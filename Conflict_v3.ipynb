# %%
from magazine_project_full import download_images_from_csv, run_pipeline

download_manifest = download_images_from_csv(
    csv_path="Magazine_final.csv",
    images_dir="./magazine_images",
    num_workers=8,
)

results = run_pipeline(
    csv_path="Magazine_final.csv",
    image_mode="local",
    images_dir="./magazine_images",
    output_dir="./project_outputs",
    epochs=5,
    batch_size=32,
)
# Out:
# Epoch 01 | train_loss=0.8260 | val_acc=0.7230 | val_macro_f1=0.7080 | val_weighted_f1=0.7079
# Epoch 02 | train_loss=0.5254 | val_acc=0.7387 | val_macro_f1=0.7330 | val_weighted_f1=0.7330
# Epoch 03 | train_loss=0.3294 | val_acc=0.7387 | val_macro_f1=0.7344 | val_weighted_f1=0.7345
# Epoch 04 | train_loss=0.1686 | val_acc=0.7446 | val_macro_f1=0.7406 | val_weighted_f1=0.7407
# Epoch 05 | train_loss=0.0779 | val_acc=0.7544 | val_macro_f1=0.7526 | val_weighted_f1=0.7526
#
# Best validation metrics:
#               precision    recall  f1-score   support
#
#            0     0.7682    0.6824    0.7227       170
#            1     0.7578    0.7219    0.7394       169
#            2     0.7411    0.8588    0.7956       170
#
#     accuracy                         0.7544       509
#    macro avg     0.7557    0.7544    0.7526       509
# weighted avg     0.7557    0.7544    0.7526       509
#
# Average validation gate weights: 0.6763162417355596 0.32368375598096194
#
# Test metrics:
#               precision    recall  f1-score   support
#
#            0     0.7343    0.6176    0.6709       170
#            1     0.7056    0.8176    0.7575       170
#            2     0.7396    0.7396    0.7396       169
#
#     accuracy                         0.7250       509
#    macro avg     0.7265    0.7250    0.7227       509
# weighted avg     0.7265    0.7250    0.7227       509
#
# Confusion matrix:
#  [[105  37  28]
#  [ 15 139  16]
#  [ 23  21 125]]
# Average test gate weights: 0.6772921216511305 0.32270787998829

# %%
results = run_pipeline(
    csv_path="Magazine_final.csv",
    image_mode="local",
    images_dir="./magazine_images",
    output_dir="./project_outputs",
    epochs=5,
    batch_size=32,
)
# Out:
# Epoch 01 | train_loss=0.8260 | val_acc=0.7230 | val_macro_f1=0.7080 | val_weighted_f1=0.7079
# Epoch 02 | train_loss=0.5254 | val_acc=0.7387 | val_macro_f1=0.7330 | val_weighted_f1=0.7330
# Epoch 03 | train_loss=0.3294 | val_acc=0.7387 | val_macro_f1=0.7344 | val_weighted_f1=0.7345
# Epoch 04 | train_loss=0.1686 | val_acc=0.7446 | val_macro_f1=0.7406 | val_weighted_f1=0.7407
# Epoch 05 | train_loss=0.0779 | val_acc=0.7544 | val_macro_f1=0.7526 | val_weighted_f1=0.7526
#
# Best validation metrics:
#               precision    recall  f1-score   support
#
#            0     0.7682    0.6824    0.7227       170
#            1     0.7578    0.7219    0.7394       169
#            2     0.7411    0.8588    0.7956       170
#
#     accuracy                         0.7544       509
#    macro avg     0.7557    0.7544    0.7526       509
# weighted avg     0.7557    0.7544    0.7526       509
#
# Average validation gate weights: 0.6763162417355596 0.32368375598096194
#
# Test metrics:
#               precision    recall  f1-score   support
#
#            0     0.7343    0.6176    0.6709       170
#            1     0.7056    0.8176    0.7575       170
#            2     0.7396    0.7396    0.7396       169
#
#     accuracy                         0.7250       509
#    macro avg     0.7265    0.7250    0.7227       509
# weighted avg     0.7265    0.7250    0.7227       509
#
# Confusion matrix:
#  [[105  37  28]
#  [ 15 139  16]
#  [ 23  21 125]]
# Average test gate weights: 0.6772921216511305 0.32270787998829
