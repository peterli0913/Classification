# %%
from magazine_project_full import download_images_from_csv, run_pipeline

# %%
csv_path = 'Magazine_final.csv'
images_dir = './magazine_images'
output_dir = './project_outputs'

# %%
download_manifest = download_images_from_csv(
    csv_path=csv_path,
    images_dir=images_dir,
    num_workers=8,
)
download_manifest.head()

# %%
results = run_pipeline(
    csv_path=csv_path,
    image_mode='local',
    images_dir=images_dir,
    output_dir=output_dir,
    epochs=5,
    batch_size=32,
)
results

# %% [markdown]
# For direct URL mode in a Python script, use:
#
# ```python
# from magazine_project_full import run_pipeline
#
# run_pipeline(
#     csv_path='Magazine_final.csv',
#     image_mode='url',
#     images_dir=None,
#     output_dir='./project_outputs_url',
#     epochs=5,
# )
# ```
